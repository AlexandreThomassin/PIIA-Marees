# %%
import tensorflow as tf
import pandas as pd
import numpy as np
# Out:
# 2022-10-28 08:44:56.067577: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-28 08:44:56.170961: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-10-28 08:44:56.170978: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-10-28 08:44:56.192861: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-10-28 08:44:56.729069: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2022-10-28 08:44:56.729149: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2022-10-28 08:44:56.729157: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
dataframe = pd.read_csv("1996_2005.csv", index_col = "Date", parse_dates = True)

# %%
value_serie = dataframe["Valeur"]
n = len(value_serie)
train_values = value_serie.values[:n//2].reshape(-1,1)
test_values = value_serie.values[n//2:].reshape(-1,1)

# %%
print(f"Valeurs d'entrainement : {train_values}")
print(f"Valeurs de test : {test_values}")
# Out:
# Valeurs d'entrainement : [[5.88]
#  [5.89]
#  [5.9 ]
#  ...
#  [5.13]
#  [5.  ]
#  [4.93]]
# Valeurs de test : [[4.75 ]
#  [4.68 ]
#  [4.5  ]
#  ...
#  [1.91 ]
#  [2.087]
#  [2.276]]

# %%
def create_window(dataset, start_index, end_index, history_size):
    data = []
    labels = []

    start_index = start_index + history_size
    if end_index is None:
        end_index = len(dataset)

    for i in range(start_index, end_index-history_size):
        indices = range(i, i+history_size)
        data.append(np.reshape(dataset[indices], (history_size, 1)))
        labels.append(dataset[i+history_size])

    return np.array(data), np.array(labels)

# %%
train_features, train_labels = create_window(train_values, 0, None, 5)
test_features, test_labels = create_window(test_values, 0, None,5)

#print(train_features)
#print(train_labels)

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((train_features, train_labels)).batch(100).repeat()
test_dataset = tf.data.Dataset.from_tensor_slices((test_features, test_labels)).batch(100).repeat()
# Out:
# 2022-10-28 08:45:44.700012: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:966] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2022-10-28 08:45:44.702758: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-10-28 08:45:44.702814: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory
# 2022-10-28 08:45:44.702854: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory
# 2022-10-28 08:45:44.702895: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcufft.so.10'; dlerror: libcufft.so.10: cannot open shared object file: No such file or directory
# 2022-10-28 08:45:44.702935: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcurand.so.10'; dlerror: libcurand.so.10: cannot open shared object file: No such file or directory
# 2022-10-28 08:45:44.702974: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusolver.so.11'; dlerror: libcusolver.so.11: cannot open shared object file: No such file or directory
# 2022-10-28 08:45:44.703012: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory
# 2022-10-28 08:45:44.703050: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2022-10-28 08:45:44.703058: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1934] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2022-10-28 08:45:44.703932: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.LSTM(8, input_shape=(5, 1)),
    tf.keras.layers.Dense(1)
])
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
history = model.fit(
    train_dataset,
    epochs=100,
    steps_per_epoch=20,
    validation_data=test_dataset,
    validation_steps=3
)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 2s 21ms/step - loss: 11.0046 - val_loss: 8.2136
# Epoch 2/100
# 20/20 [==============================] - 0s 5ms/step - loss: 8.9657 - val_loss: 6.4652
# Epoch 3/100
# 20/20 [==============================] - 0s 6ms/step - loss: 5.6757 - val_loss: 4.9151
# Epoch 4/100
# 20/20 [==============================] - 0s 7ms/step - loss: 4.3857 - val_loss: 3.7054
# Epoch 5/100
# 20/20 [==============================] - 0s 5ms/step - loss: 3.1313 - val_loss: 2.8424
# Epoch 6/100
# 20/20 [==============================] - 0s 7ms/step - loss: 2.9338 - val_loss: 2.2253
# Epoch 7/100
# 20/20 [==============================] - 0s 6ms/step - loss: 2.9806 - val_loss: 1.6763
# Epoch 8/100
# 20/20 [==============================] - 0s 7ms/step - loss: 1.4794 - val_loss: 1.3204
# Epoch 9/100
# 20/20 [==============================] - 0s 6ms/step - loss: 1.3770 - val_loss: 1.0260
# Epoch 10/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.9194 - val_loss: 0.8280
# Epoch 11/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.9188 - val_loss: 0.6513
# Epoch 12/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.6213 - val_loss: 0.5259
# Epoch 13/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.7231 - val_loss: 0.4362
# Epoch 14/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3636 - val_loss: 0.3687
# Epoch 15/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3233 - val_loss: 0.3249
# Epoch 16/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3905 - val_loss: 0.2737
# Epoch 17/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2073 - val_loss: 0.2417
# Epoch 18/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.4806 - val_loss: 0.2062
# Epoch 19/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1948 - val_loss: 0.1830
# Epoch 20/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3100 - val_loss: 0.1618
# Epoch 21/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1394 - val_loss: 0.1437
# Epoch 22/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1855 - val_loss: 0.1285
# Epoch 23/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3315 - val_loss: 0.1099
# Epoch 24/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2115 - val_loss: 0.0975
# Epoch 25/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2198 - val_loss: 0.0855
# Epoch 26/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0658 - val_loss: 0.0774
# Epoch 27/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1612 - val_loss: 0.0713
# Epoch 28/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1151 - val_loss: 0.0672
# Epoch 29/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1544 - val_loss: 0.0585
# Epoch 30/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0784 - val_loss: 0.0536
# Epoch 31/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0583 - val_loss: 0.0508
# Epoch 32/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1510 - val_loss: 0.0489
# Epoch 33/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0583 - val_loss: 0.0458
# Epoch 34/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1755 - val_loss: 0.0404
# Epoch 35/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0622 - val_loss: 0.0386
# Epoch 36/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0721 - val_loss: 0.0347
# Epoch 37/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1041 - val_loss: 0.0357
# Epoch 38/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0497 - val_loss: 0.0340
# Epoch 39/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1099 - val_loss: 0.0285
# Epoch 40/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0418 - val_loss: 0.0282
# Epoch 41/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0818 - val_loss: 0.0263
# Epoch 42/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0456 - val_loss: 0.0243
# Epoch 43/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0296 - val_loss: 0.0234
# Epoch 44/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0489 - val_loss: 0.0243
# Epoch 45/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0396 - val_loss: 0.0234
# Epoch 46/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0355 - val_loss: 0.0230
# Epoch 47/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0097 - val_loss: 0.0224
# Epoch 48/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0029 - val_loss: 0.0226
# Epoch 49/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0016 - val_loss: 0.0218
# Epoch 50/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0363 - val_loss: 0.0216
# Epoch 51/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0208 - val_loss: 0.0200
# Epoch 52/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0517 - val_loss: 0.0207
# Epoch 53/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0233 - val_loss: 0.0183
# Epoch 54/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0449 - val_loss: 0.0173
# Epoch 55/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0213 - val_loss: 0.0160
# Epoch 56/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0173 - val_loss: 0.0157
# Epoch 57/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0671 - val_loss: 0.0179
# Epoch 58/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0233 - val_loss: 0.0158
# Epoch 59/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0777 - val_loss: 0.0159
# Epoch 60/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0174 - val_loss: 0.0138
# Epoch 61/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0296 - val_loss: 0.0131
# Epoch 62/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0594 - val_loss: 0.0138
# Epoch 63/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0214 - val_loss: 0.0126
# Epoch 64/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0595 - val_loss: 0.0131
# Epoch 65/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0167 - val_loss: 0.0121
# Epoch 66/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0186 - val_loss: 0.0115
# Epoch 67/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0165 - val_loss: 0.0111
# Epoch 68/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0400 - val_loss: 0.0113
# Epoch 69/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0252 - val_loss: 0.0108
# Epoch 70/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0245 - val_loss: 0.0107
# Epoch 71/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0183 - val_loss: 0.0101
# Epoch 72/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0108 - val_loss: 0.0098
# Epoch 73/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0472 - val_loss: 0.0107
# Epoch 74/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0132 - val_loss: 0.0098
# Epoch 75/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0522 - val_loss: 0.0110
# Epoch 76/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0051 - val_loss: 0.0098
# Epoch 77/100
# 20/20 [==============================] - 0s 4ms/step - loss: 5.5071e-04 - val_loss: 0.0092
# Epoch 78/100
# 20/20 [==============================] - 0s 5ms/step - loss: 9.3529e-04 - val_loss: 0.0094
# Epoch 79/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0031 - val_loss: 0.0104
# Epoch 80/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0041 - val_loss: 0.0107
# Epoch 81/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0028 - val_loss: 0.0095
# Epoch 82/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0458 - val_loss: 0.0100
# Epoch 83/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0099 - val_loss: 0.0088
# Epoch 84/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0162 - val_loss: 0.0085
# Epoch 85/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0141 - val_loss: 0.0085
# Epoch 86/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0109 - val_loss: 0.0079
# Epoch 87/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0154 - val_loss: 0.0082
# Epoch 88/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0101 - val_loss: 0.0077
# Epoch 89/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0115 - val_loss: 0.0076
# Epoch 90/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0074 - val_loss: 0.0077
# Epoch 91/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0180 - val_loss: 0.0077
# Epoch 92/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0107 - val_loss: 0.0072
# Epoch 93/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0348 - val_loss: 0.0096
# Epoch 94/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0103 - val_loss: 0.0070
# Epoch 95/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0082 - val_loss: 0.0067
# Epoch 96/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0288 - val_loss: 0.0074
# Epoch 97/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0102 - val_loss: 0.0065
# Epoch 98/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0307 - val_loss: 0.0085
# Epoch 99/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0074 - val_loss: 0.0071
# Epoch 100/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0077 - val_loss: 0.0064

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

def plot_history(history):
    loss = history.history["loss"]
    val_loss = history.history["val_loss"]
    plt.plot(np.arange(len(loss)) + 0.5, loss, "b.-", label="Training loss")
    plt.plot(np.arange(len(val_loss)) + 1, val_loss, "r.-", label="Validation loss")
    plt.gca().xaxis.set_major_locator(mpl.ticker.MaxNLocator(integer=True))
    plt.axis([1, 100, 0, max(max(loss), max(val_loss))])
    plt.legend(fontsize=14)
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.grid(True)
    plt.show()

# %%
#print(history.history)
plot_history(history)

# %%
predictions = model.predict(train_features)
# Out:
# 9882/9882 [==============================] - 13s 1ms/step

# %%
#print(predictions)
#print(len(predictions))
#print(value_serie.values)
begin = 300_000
end = 301_000
    
time = [i for i in range(end)]    


fig = plt.figure(figsize=(15,5))

ax = fig.add_subplot(1, 1, 1)
ax.grid(True)

plt.plot(time[begin:end], predictions[begin-10:end-10], label = "Predictions")
plt.plot(time[begin:end], value_serie.values[begin:end], label = "Real Data")
plt.legend()
plt.show()
